# %% [markdown]
# # Анализ госзакупок по запросу покупок лицензий Битрикс24

# %%
import pandas as pd
import unicodedata
import sys

# %%
tenders = pd.read_excel('data/bitrix24.xlsx')

# %%
tenders['customer'] = tenders['customer'].apply(lambda s: s.lower())

# %%
tenders = tenders.dropna()

# %%
stopwords = {
    '"': None,
    'общество': None,
    'с': None,
    'ограниченной': None,
    'ответственностью': None,
    'ооо': None,
    'индивидуальный': None,
    'предприниматель': None,
    'ип': None,
}

# %%
tenders['vendor'] = tenders['vendor'].apply(lambda s: s.lower().translate(stopwords))
# Out:
# D:\Python\3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
'общество с ограниченной ответственностью "симай"'.translate(stopwords)
# Out:
# 'общество с ограниченной ответственностью "симай"'

# %%
tenders
# Out:
#           date           tender_id  fz_id  \
# 0   2015-11-11  101200009715000018     44
# 1   2015-11-11  101200009715000018     44
# 2   2015-11-11  101200009715000018     44
# 3   2015-11-11  101200009715000018     44
# 4   2015-11-11  101200009715000018     44
# ..         ...                 ...    ...
# 125 2019-07-22         31908122598    223
# 126 2019-07-22         31908122598    223
# 127 2019-07-22         31908122598    223
# 128 2019-07-22         31908122598    223
# 129 2019-07-22         31908122598    223
#
#                                               customer  customer_reg  \
# 0      управление делами главы республики башкортостан             2
# 1      управление делами главы республики башкортостан             2
# 2      управление делами главы республики башкортостан             2
# 3      управление делами главы республики башкортостан             2
# 4      управление делами главы республики башкортостан             2
# ..                                                 ...           ...
# 125  федеральное государственное бюджетное научное ...            33
# 126  федеральное государственное бюджетное научное ...            33
# 127  федеральное государственное бюджетное научное ...            33
# 128  федеральное государственное бюджетное научное ...            33
# 129  федеральное государственное бюджетное научное ...            33
#
#                                                 vendor  vendor_reg  \
# 0     общество с ограниченной ответственностью "симай"         2.0
# 1    общество с ограниченной ответственностью "софт...        78.0
# 2    общество с ограниченной ответственностью аир-софт         2.0
# 3    общество с ограниченной ответственностью "софт...        78.0
# 4    индивидуальный предприниматель ладарева марина...        13.0
# ..                                                 ...         ...
# 125  общество с ограниченной ответственностью "форм...        77.0
# 126  индивидуальный предприниматель сергушкин алекс...        74.0
# 127  общество с ограниченной ответственностью "инфо...        78.0
# 128  общество с ограниченной ответственностью "вис ...        77.0
# 129  общество с ограниченной ответственностью "студ...        63.0
#
#      start_price  last_price  is_winner
# 0       479100.0      407235          1
# 1       479100.0  407 235,00          0
# 2       479100.0  407 235,00          0
# 3       479100.0  407 235,00          0
# 4       479100.0  407 235,00          0
# ..           ...         ...        ...
# 125     216380.0      215760          0
# 126     216380.0      215760          0
# 127     216380.0      215760          0
# 128     216380.0      215760          0
# 129     216380.0      215760          0
#
# [129 rows x 10 columns]

# %%
mask = list(map(lambda x: True if type(x) == 'str' else False, tenders['vendor']))

# %%
for s in tenders['vendor'].values:
    print(s, type(s))
# Out:
# Общество с ограниченной ответственностью "Симай" <class 'str'>
# Общество с ограниченной ответственностью "Софт Билдинг" <class 'str'>
# Общество с Ограниченной Ответственностью АИР-СОФТ <class 'str'>
# Общество с ограниченной ответственностью "СофтБаланс ИТ" <class 'str'>
# Индивидуальный предприниматель Ладарева Марина Алексеевна <class 'str'>
# Общество с ограниченной ответственностью «Навигатор» <class 'str'>
# Общество с ограниченной ответственностью "Симай" <class 'str'>
# Общество с ограниченной ответственностью "САН-ВЕБ <class 'str'>
# Общество с ограниченной ответственностью «Аш 2 о дизайн» <class 'str'>
# Общество с ограниченной ответственностью «ПродвигаеФФ.ру» <class 'str'>
# Общество с ограниченной ответственностью "Софт Билдинг" <class 'str'>
# Общество с ограниченной ответственностью  «Навигатор» <class 'str'>
# Общество с ограниченной ответственностью "ВИА" <class 'str'>
# Общество с ограниченной ответственностью "Ай Ти Констракт" <class 'str'>
# Общество с ограниченной ответственностью "САЙТ" <class 'str'>
# Общество с ограниченной ответственностью Сманлайн <class 'str'>
# ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "СВЕКТОР+" <class 'str'>
# Общество с Ограниченной Ответственностью АИР-СОФТ <class 'str'>
# ООО «Новые технологии НН» <class 'str'>
# ООО "ЦЛПО" <class 'str'>
# ООО 'ПродвигаеФФ.ру' <class 'str'>
# ООО "СИНЕКТИКА" <class 'str'>
# Общество с ограниченной ответственностью Региональный сервисный центр "Форус" <class 'str'>
# Общество с Ограниченной Ответственностью "Научно-Техническое Объединение "ИНТ" <class 'str'>
# Общество с ограниченной ответственностью "Симай" <class 'str'>
# ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "ВЕБСОФТ" <class 'str'>
# Общество с ограниченной ответственностью «ИЦ Элит-профит» <class 'str'>
# Общество с ограниченной ответственностью "Софт Билдинг" <class 'str'>
# Общество с ограниченной ответственностью Сманлайн <class 'str'>
# Общество с ограниченной ответственностью «Лаборатория информационных ресурсов» <class 'str'>
# Общество с Ограниченной Ответственностью АИР-СОФТ <class 'str'>
# Общество с ограниченной ответственностью «ПродвигаеФФ.ру» <class 'str'>
# ООО "ПУСК" <class 'str'>
# ООО "Джилаб" <class 'str'>
# Общество с ограниченной ответственностью «Свектор+» <class 'str'>
# Общество с ограниченной ответственностью "СОЛО ГРУП" <class 'str'>
# Общество с ограниченной ответственностью «Лаборатория информационных ресурсов» <class 'str'>
# Общество с ограниченной ответственностью "Айтекс"" <class 'str'>
# ООО "ЦИТАДЕЛЬ" <class 'str'>
# Общество с ограниченной ответственностью «Софт Билдинг» <class 'str'>
# Общество с ограниченной ответственностью «Свектор+» <class 'str'>
# Общество с ограниченной ответственностью "ЛУГАКОНСАЛТИНГ" <class 'str'>
# Общество с ограниченной ответственностью "Софт Билдинг" <class 'str'>
# ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "ДУДОРОФФ" <class 'str'>
# ИП Федотов Сергей Александрович <class 'str'>
# ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "ВЕБСОФТ" <class 'str'>
# Общество с ограниченной ответственностью «ИЦ Элит-профит» <class 'str'>
# Общество с ограниченной ответственностью «ПродвигаеФФ.ру» <class 'str'>
# ИП Глебов Иван Николаевич <class 'str'>
# Общество с ограниченной ответственностью "Симай" <class 'str'>
# ИП Яшанин Артём Александрович <class 'str'>
# Общество с ограниченной ответственностью "СОЛО ГРУП" <class 'str'>
# Общество с ограниченной ответственностью "Софт Билдинг" <class 'str'>
# Общество с ограниченной ответственностью "ИТЦ КИМЕТ" <class 'str'>
# ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "КР ЦИФРОВАЯ МАСТЕРСКАЯ" <class 'str'>
# ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "ДРАЙВ" <class 'str'>
# ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "ВЕБСОФТ" <class 'str'>
# ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "СВЕКТОР+" <class 'str'>
# ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "ПИНОЛ" <class 'str'>
# ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "ОСК" <class 'str'>
# ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "СОФТ БИЛДИНГ" <class 'str'>
# ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "ПРОГРАММ ИНЖИНИРИНГ" <class 'str'>
# Индивидуальный предприниматель Лихач Роман Валерьевич <class 'str'>
# КРОТОВ ДМИТРИЙ АЛЕКСАНДРОВИЧ <class 'str'>
# ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "СОФТ БИЛДИНГ" <class 'str'>
# ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "ПРОГРАММ ИНЖИНИРИНГ" <class 'str'>
# ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "ЭЛЬДИРЕКТ" <class 'str'>
# ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "СОЦИАЛЬНЫЕ ПРОЕКТЫ" <class 'str'>
# ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "СВЕКТОР+" <class 'str'>
# ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "ФОРСАЙТЕКС ДИДЖИТАЛ АГЕНТСТВО" <class 'str'>
# ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "СМАНЛАЙН" <class 'str'>
# ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "СТУДИЯ 24" <class 'str'>
# ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "ВЕБПРАКТИК" <class 'str'>
# ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "ОВИОНТ" <class 'str'>
# ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "СОФТЕКС" <class 'str'>
# ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "ОСК" <class 'str'>
# Индивидуальный предприниматель ЕМЕЛЬЯНОВ ЮРИЙ ИГОРЕВИЧ <class 'str'>
# Индивидуальный предприниматель СКОПИНЦЕВ МИХАИЛ СЕРГЕЕВИЧ <class 'str'>
# ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "СОЦИАЛЬНЫЕ ПРОЕКТЫ" <class 'str'>
# ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "СОФТ БИЛДИНГ" <class 'str'>
# ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "ПРОГРАММ ИНЖИНИРИНГ" <class 'str'>
# Индивидуальный предприниматель ПЕТРОВ АНДРЕЙ АНАТОЛЬЕВИЧ <class 'str'>
# Индивидуальный предприниматель МУХИН ДМИТРИЙ СЕРГЕЕВИЧ <class 'str'>
# ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "УМНЫЕ РЕШЕНИЯ" <class 'str'>
# Общество с Ограниченной Ответственностью "ОСК" <class 'str'>
# ООО "СФЕРО" <class 'str'>
# ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "АИР-СОФТ"  <class 'str'>
# ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "АПЛЭБ" <class 'str'>
# ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "ВЕБСОФТ" <class 'str'>
# ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "СИМАЙ" <class 'str'>
# ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "ВЭБТУЭЙДЖ" <class 'str'>
# ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "ФЬЮЖН" <class 'str'>
# ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "СОФТ БИЛДИНГ" <class 'str'>
# ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "АИР-СОФТ"  <class 'str'>
# ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "ВЕБСОФТ" <class 'str'>
# БРОВКИЛЛО СЕРГЕЙ АЛЕКСАНДРОВИЧ <class 'str'>
# ИСАЕВ АНТОН АЛЕКСАНДРОВИЧ  <class 'str'>
# ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "ВЕБПРАКТИК" <class 'str'>
# ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "ПРАВОВЫЕ СИСТЕМЫ" <class 'str'>
# ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "БАЙКАЛСОФТ" <class 'str'>
# ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "СОФТ БИЛДИНГ" <class 'str'>
# ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "ФОРМУЛА ИТ" <class 'str'>
# ПЫХТИНА ЕКАТЕРИНА АНАТОЛЬЕВНА <class 'str'>
# ВИХАРЕВ КИРИЛЛ ВИТАЛЬЕВИЧ <class 'str'>
# ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "СОЦИАЛЬНЫЕ ПРОЕКТЫ" <class 'str'>
# Осецкий Дмитрий Юрьевич <class 'str'>
# ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "ПРОГРАММ ИНЖИНИРИНГ" <class 'str'>
# ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "ОСК" <class 'str'>
# ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "ВЕБСОФТ" <class 'str'>
# nan <class 'float'>
# ООО "Альтерсофт" <class 'str'>
# ООО "Фьюжн" <class 'str'>
# ООО "Информационные технологии Сервис" <class 'str'>
# ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "АПЛЭБ" <class 'str'>
# ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "РУСОНИКС" <class 'str'>
# ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "АЙТЕКС" <class 'str'>
# ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "ПРОГРАММ ИНЖИНИРИНГ" <class 'str'>
# ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "СОЦИАЛЬНЫЕ ПРОЕКТЫ" <class 'str'>
# ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "ВЕБСОФТ" <class 'str'>
# ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "ПРОДВИГАЕФФ.РУ" <class 'str'>
# ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "СОФТ БИЛДИНГ" <class 'str'>
# ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "СМАНЛАЙН" <class 'str'>
# ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "ВЕБПРАКТИК" <class 'str'>
# ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "СЕРТИФИЦИРОВАННЫЕ ИНФОРМАЦИОННЫЕ СИСТЕМЫ ГРУП" <class 'str'>
# ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "ПИНОЛ" <class 'str'>
# ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "ФОРМУЛА ИТ" <class 'str'>
# ИНДИВИДУАЛЬНЫЙ ПРЕДПРИНИМАТЕЛЬ СЕРГУШКИН АЛЕКСЕЙ ВАЛЕРЬЕВИЧ <class 'str'>
# ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "ИНФОНОВА.ПРО" <class 'str'>
# ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "ВИС ЦЕНТР" <class 'str'>
# ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "СТУДИЯ АВТОМАТИЗАЦИИ" <class 'str'>
